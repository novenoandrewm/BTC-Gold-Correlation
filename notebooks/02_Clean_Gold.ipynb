# %% [markdown]
# # 02 – Clean Gold Monthly Prices
#
# This notebook takes the raw monthly gold price file and turns it into a clean,
# analysis-ready time series that will be used in all later notebooks.
#
# **Input**
#
# - `data/raw/gold_monthly_price.csv`
#   Columns:
#   - `Date` (string, format `YYYY-MM`)
#   - `Price` (gold price in USD)
#
# **Objectives**
#
# 1. Parse the `Date` and `Price` columns into proper types.
# 2. Enforce one observation per calendar month and construct a monthly
#    end-of-month (EOM) time index.
# 3. Filter the series to the target study window (2020–2025).
# 4. Run basic quality checks (date range, row count, missing months).
# 5. Save a cleaned CSV that will be consumed by later notebooks.

# %% [markdown]
# 1. Import & Path

# %%
from pathlib import Path
import pandas as pd


RAW = Path("data/raw")
OUT = Path("data/interim"); OUT.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 2. Load, parse, and standardise the monthly gold series
#
# In the next code cell we:
#
# 1. **Load** `gold_monthly_price.csv` from `data/raw/`.
# 2. **Parse types**
#    - Convert `Date` strings like `"2020-01"` to a proper monthly timestamp.
#    - Convert `Price` to a numeric `Gold_USD` column.
# 3. **Drop invalid rows** where either the parsed date or price is missing.
# 4. **Enforce one observation per month**
#    - Create a `Month` period index.
#    - Group by `Month` and take the **last available price** in each month.
#    - Convert the monthly period index to an end-of-month (`EOM`) `DatetimeIndex`.
# 5. **Filter the analysis window**
#    - Keep observations from **2020-01-31** up to **2025-12-31**.
#    - The raw dataset actually ends in **2025-07**, so we end up with data from
#      **January 2020 to July 2025**.
# 6. **Quality checks**
#    - Compare the cleaned index against all expected month-end dates between
#      2020-01 and 2025-12.
#    - Print:
#      - the number of rows,
#      - the observed date range,
#      - and any missing months.
# 7. **Export**
#    - Save the cleaned series to
#      `data/interim/gold_monthly_clean_2020_2025.csv`
#      with `Date` as the EOM index.
#
# This notebook therefore defines the canonical gold price series used throughout
# the rest of the project.

# %% [markdown]
# 2. Load, Clean & Filter

# %%
# Load file
df = pd.read_csv(RAW / "gold_monthly_price.csv")
display(df.head(3)); df.info()
assert {"Date","Price"}.issubset(df.columns), df.columns.tolist()

# Parse data type 
dates = pd.to_datetime(df["Date"].astype(str).str.strip(), format="%Y-%m", errors="coerce")
prices = pd.to_numeric(df["Price"], errors="coerce")

gold = (pd.DataFrame({"Date": dates, "Gold_USD": prices})
        .dropna(subset=["Date","Gold_USD"])
        .sort_values("Date"))

# Make sure only obserbvation one per month
gold["Month"] = gold["Date"].dt.to_period("M")
gold_m = (gold.drop(columns="Date")
          .drop_duplicates(subset=["Month"], keep="last")
          .set_index("Month")
          .sort_index())

# Use last month index (EOM)
gold_m.index = gold_m.index.to_timestamp("M")
gold_m.index.name = "Date"
gold_m.head()

# Filter 2020-2025
gold_m = gold_m.loc["2020-01-31":"2025-12-31"]

# Quality control (QC)
expected = pd.period_range("2020-01", "2025-12",freq="M").to_timestamp("M")
missing = expected.difference(gold_m.index)

print("Rows          :", len(gold_m), "(target 72)")
print("Range         :", gold_m.index.min(), "->", gold_m.index.max())
print("Missing month :", len(missing), list(missing)[:8])

# Save to interim
out_file = OUT / "gold_monthly_clean_2020_2025.csv"
gold_m.to_csv(out_file, index_label="Date")
print("Saved ->", out_file.resolve())
# Out:
#       Date  Price
# 0  1833-01  18.93
# 1  1833-02  18.93
# 2  1833-03  18.93
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2311 entries, 0 to 2310
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2311 non-null   object
#  1   Price   2311 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 36.2+ KB
# Rows          : 67 (target 72)
# Range         : 2020-01-31 00:00:00 -> 2025-07-31 00:00:00
# Missing month : 5 [Timestamp('2025-08-31 00:00:00'), Timestamp('2025-09-30 00:00:00'), Timestamp('2025-10-31 00:00:00'), Timestamp('2025-11-30 00:00:00'), Timestamp('2025-12-31 00:00:00')]
# Saved -> C:\Users\Noveno\OneDrive\CA1-BTC-Gold-Correlation\data\interim\gold_monthly_clean_2020_2025.csv
