# %% [markdown]
# # 03 – Clean BTC Hourly → Monthly End-of-Month Close
#
# This notebook converts the raw **hourly** Bitcoin price file into a clean
# **monthly end-of-month (EOM) close** series that is compatible with the gold
# series prepared in `02_Clean_Gold.ipynb`.
#
# **Input**
#
# - `data/raw/btc-hourly-price_2015_2025.csv`
#   - `TIME_UNIX` – Unix timestamp (epoch), in seconds or milliseconds.
#   - `CLOSE_PRICE` – hourly BTC closing price in USD.
#
# **Objectives**
#
# 1. Load the raw hourly BTC data from `data/raw/`.
# 2. Detect the correct epoch unit (seconds vs milliseconds) and parse
#    timestamps as UTC datetimes.
# 3. Clean `CLOSE_PRICE` to a numeric `BTC_USD` series and drop invalid rows.
# 4. De-duplicate timestamps to ensure at most one observation per hour.
# 5. Filter the series to the analysis window **2020-01-01 → 2025-12-31 (UTC)**.
# 6. Resample to **monthly EOM closes** using the last available hourly price in
#    each calendar month.
# 7. Run basic QC:
#    - check the monthly date range,
#    - compare the number of months with the expected 2020–2025 window,
#    - list any missing months.
# 8. Save the cleaned monthly series to `data/interim/btc_monthly_close_2020_2025.csv`
#    for use in later notebooks (merge, EDA, correlation, robustness).
#
# ## 1. Imports and path configuration
#
# We first import the required libraries (`pandas` and `pathlib.Path`) and set up
# two root folders:
#
# - `RAW` – points to `data/raw/`, where immutable input files live.
# - `OUT` – points to `data/interim/`, where intermediate cleaned data are stored.
#
# If `OUT` does not exist, we create it. This makes the notebook reproducible from
# a fresh clone without manual directory setup.

# %% [markdown]
# 1. Import & Path

# %%
from pathlib import Path
import pandas as pd

RAW = Path("data/raw")
OUT = Path("data/interim"); OUT.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 2. Load and parse the raw BTC hourly series
#
# In the next code cell we:
#
# 1. **Load** only the columns we actually need:
#    - `TIME_UNIX` (timestamp in epoch units),
#    - `CLOSE_PRICE` (hourly close in USD),
#    from `data/raw/btc-hourly-price_2015_2025.csv`.
#
# 2. **Verify schema**
#    - Assert that both columns are present; fail early if the file structure ever
#      changes.
#
# 3. **Detect epoch unit (seconds vs milliseconds)**
#    - Convert `TIME_UNIX` to a numeric series.
#    - Use the median value to infer whether the timestamps are in seconds
#      (~1e9) or milliseconds (~1e12).
#    - Parse to a timezone-aware UTC datetime with `pd.to_datetime(..., utc=True)`.
#
# 4. **Clean the close price**
#    - Coerce `CLOSE_PRICE` to string, strip any `$` or `,` characters,
#    - then convert to a numeric `BTC_USD` column, coercing bad values to `NaN`.
#
# 5. **Build the working DataFrame**
#    - Combine the parsed datetime (`dt`) and price (`BTC_USD`) into a new
#      `btc` DataFrame.
#    - Drop rows where either the timestamp or price failed to parse.
#    - Sort the data by `dt` so that later resampling uses a clean time order.
#
# 6. **Quick QC**
#    - Print the **parse rate** (fraction of rows with a valid timestamp) and the
#      overall **date range** of the hourly series.
#    - Count how many prices are non-positive (`BTC_USD <= 0`).
#
# In our data, the parse rate is effectively **100%** and there are **no
# non-positive prices**, so we can treat the raw BTC file as structurally sound
# and focus on de-duplication, windowing, and resampling in the next step.

# %%
# File location
btc_path = RAW / "btc-hourly-price_2015_2025.csv"
df = pd.read_csv(btc_path, usecols=["TIME_UNIX","CLOSE_PRICE"], low_memory=False)

assert {"TIME_UNIX","CLOSE_PRICE"}.issubset(df.columns), df.columns.tolist()
display(df.head(3)); df.info()

# Detect epoch unit (seconds vs milliseconds)
unix = pd.to_numeric(df["TIME_UNIX"], errors="coerce")
unit = "ms" if unix.dropna().median() > 1e12 else "s"

# Datetime UTC & numeric price (clear $, , if any)
dt_utc = pd.to_datetime(unix, unit=unit, utc=True, errors="coerce")
close = pd.to_numeric(
    df["CLOSE_PRICE"].astype(str).str.replace(r"[,$]", "", regex=True),
    errors="coerce")

btc = (
    pd.DataFrame({"dt": dt_utc, "BTC_USD": close})
      .dropna()
      .sort_values("dt"))

print("Parse rate:", f"{dt_utc.notna().mean():.2%}",
      "| Range:", btc["dt"].min(), "->", btc["dt"].max())
print("Non-positive price:", int((btc["BTC_USD"] <= 0).sum()))
# Out:
#     TIME_UNIX  CLOSE_PRICE
# 0  1416031200       396.15
# 1  1416034800       397.15
# 2  1416038400       399.90
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96042 entries, 0 to 96041
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TIME_UNIX    96042 non-null  int64
#  1   CLOSE_PRICE  96042 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 1.5 MB
# Parse rate: 100.00% | Range: 2014-11-15 06:00:00+00:00 -> 2025-10-29 23:00:00+00:00
# Non-positive price: 0

# %% [markdown]
# ## 3. De-duplicate, filter to 2020–2025, resample to monthly EOM, and save
#
# With a clean hourly BTC series, we now:
#
# 1. **Remove duplicated timestamps**
#    - Use `~btc["dt"].duplicated(keep="last")` to keep only the last observation
#      for each timestamp.
#    - This protects us against any accidental double-rows in the raw file.
#
# 2. **Filter the analysis window (UTC)**
#    - Define:
#      - `start = 2020-01-01`,
#      - `end   = 2025-12-31`.
#    - Keep only rows where `dt` lies in this interval.
#    - Print the number of hourly rows that remain in the 2020–2025 window
#      (≈ 51,000 hourly observations).
#
# 3. **Resample to monthly end-of-month closes**
#    - Set `dt` as the index and take `.resample("M").last()` on `BTC_USD`.
#    - This produces one **end-of-month close** per calendar month, which is
#      standard for portfolio and correlation analysis.
#    - Drop the timezone and rename the index to `Date` so that it matches the
#      cleaned gold file.
#
# 4. **Quality control on the monthly series**
#    - Construct the expected set of EOM dates from 2020-01-31 to 2025-12-31.
#    - Compare this to the actual index of the resampled series.
#    - Report:
#      - the number of monthly rows,
#      - the observed date range,
#      - and any missing months.
#
#    At the time of writing, this yields **70** monthly observations from
#    **2020-01-31** to **2025-10-31**, leaving **November and December 2025**
#    missing because the raw BTC file ends on **2025-10-29**.
#
#    We do **not** forward-fill or invent prices for these months; instead, the
#    inner join in `04_Merge_Align.ipynb` will naturally drop any months where
#    either BTC or gold is missing.
#
# 5. **Export the cleaned BTC monthly closes**
#    - Save the final monthly series to:
#      - `data/interim/btc_monthly_close_2020_2025.csv`
#    - The file uses `Date` (EOM) as the first column and `BTC_USD` as the
#      monthly closing price.
#
# This notebook therefore defines the canonical **BTC monthly EOM close series**
# used in all subsequent EDA, correlation, and robustness notebooks.

# %%
# Deduplicate timestamp, filter 2020–2025
btc = btc[~btc["dt"].duplicated(keep="last")]

start = pd.Timestamp("2020-01-01", tz="UTC")
end   = pd.Timestamp("2025-12-31", tz="UTC")
btc   = btc[(btc["dt"] >= start) & (btc["dt"] <= end)]
print("Rows (2020–2025) :", len(btc))

# Resample to end-of-month close
btc_m = btc.set_index("dt")["BTC_USD"].resample("M").last().to_frame()

# Remove timezone from index
btc_m.index = btc_m.index.tz_localize(None)
btc_m.index.name = "Date"

# Quality control (QC)
expected = pd.period_range("2020-01", "2025-12", freq="M").to_timestamp("M")
missing = expected.difference(btc_m.index)

print("Monthly rows     :", len(btc_m),
      "| Range :", btc_m.index.min(), "->", btc_m.index.max())
print("Missing months   :", len(missing), list(missing)[:8])

# Save
out_file = OUT / "btc_monthly_close_2020_2025.csv"
btc_m.to_csv(out_file, index_label="Date")
print("Saved ->", out_file.resolve())
# Out:
# Rows (2020–2025) : 51096
# Monthly rows     : 70 | Range : 2020-01-31 00:00:00 -> 2025-10-31 00:00:00
# Missing months   : 2 [Timestamp('2025-11-30 00:00:00'), Timestamp('2025-12-31 00:00:00')]
# Saved -> C:\Users\Noveno\OneDrive\CA1-BTC-Gold-Correlation\data\interim\btc_monthly_close_2020_2025.csv
# C:\Users\Noveno\AppData\Local\Temp\ipykernel_15488\3805360058.py:10: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   btc_m = btc.set_index("dt")["BTC_USD"].resample("M").last().to_frame()
